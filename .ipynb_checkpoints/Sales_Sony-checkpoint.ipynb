# %% [markdown]
# # Importing the packages

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
from scipy.stats import zscore
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn import linear_model
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline
# Out:
# C:\Users\91707\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:35: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps,
# C:\Users\91707\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:597: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# C:\Users\91707\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:836: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# C:\Users\91707\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# C:\Users\91707\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1097: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# C:\Users\91707\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1344: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# C:\Users\91707\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1480: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# C:\Users\91707\Anaconda3\lib\site-packages\sklearn\linear_model\randomized_l1.py:152: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   precompute=False, eps=np.finfo(np.float).eps,
# C:\Users\91707\Anaconda3\lib\site-packages\sklearn\linear_model\randomized_l1.py:320: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, random_state=None,
# C:\Users\91707\Anaconda3\lib\site-packages\sklearn\linear_model\randomized_l1.py:580: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=4 * np.finfo(np.float).eps, n_jobs=None,

# %% [markdown]
# # Collecting the sales data

# %%
sales=pd.read_csv(r"C:\Users\91707\Desktop\0Data Science  Programme Material\Data Science Case Studies\06 MLAI  Module4 Machine Learning\8 Linear Regression\G.csv")

# %%
sales.shape
# Out:
# (56, 3)

# %%
sales.tail(20)
# Out:
#      Sales   Advt    PC
# 36   42.02   4.30  2.74
# 37   40.35   2.70  3.27
# 38   46.89   4.59  3.30
# 39   54.10   4.54  3.41
# 40   70.13   8.87  3.85
# 41   63.37   3.17  4.10
# 42   74.01   7.44  4.14
# 43   86.63   8.33  4.89
# 44   95.17   9.00  5.22
# 45   90.63   5.08  6.02
# 46  105.09  11.18  6.64
# 47  120.29  10.18  7.50
# 48  121.83  11.03  7.11
# 49  108.58   5.67  7.19
# 50  121.60   9.58  9.19
# 51  119.49  10.37  8.04
# 52  144.17  17.33  9.85
# 53  128.90   4.10  9.58
# 54   42.02   4.30  2.74
# 55   40.35   2.70  3.27

# %%
sales.duplicated().any()
# Out:
# True

# %%
sales.columns
# Out:
# Index(['Sales', 'Advt', 'PC'], dtype='object')

# %%
type(sales)
# Out:
# pandas.core.frame.DataFrame

# %%
sales.describe()
# Out:
# <bound method NDFrame.describe of      Sales   Advt    PC
# 0    42.02   4.30  2.74
# 1    40.35   2.70  3.27
# 2    46.89   4.59  3.30
# 3    54.10   4.54  3.41
# 4    70.13   8.87  3.85
# 5    63.37   3.17  4.10
# 6    74.01   7.44  4.14
# 7    86.63   8.33  4.89
# 8    95.17   9.00  5.22
# 9    90.63   5.08  6.02
# 10  105.09  11.18  6.64
# 11  120.29  10.18  7.50
# 12  121.83  11.03  7.11
# 13  108.58   5.67  7.19
# 14  121.60   9.58  9.19
# 15  119.49  10.37  8.04
# 16  144.17  17.33  9.85
# 17  128.90   4.10  9.58
# 18   42.02   4.30  2.74
# 19   40.35   2.70  3.27
# 20   46.89   4.59  3.30
# 21   54.10   4.54  3.41
# 22   70.13   8.87  3.85
# 23   63.37   3.17  4.10
# 24   74.01   7.44  4.14
# 25   86.63   8.33  4.89
# 26   95.17   9.00  5.22
# 27   90.63   5.08  6.02
# 28  105.09  11.18  6.64
# 29  120.29  10.18  7.50
# 30  121.83  11.03  7.11
# 31  108.58   5.67  7.19
# 32  121.60   9.58  9.19
# 33  119.49  10.37  8.04
# 34  144.17  17.33  9.85
# 35  128.90   4.10  9.58
# 36   42.02   4.30  2.74
# 37   40.35   2.70  3.27
# 38   46.89   4.59  3.30
# 39   54.10   4.54  3.41
# 40   70.13   8.87  3.85
# 41   63.37   3.17  4.10
# 42   74.01   7.44  4.14
# 43   86.63   8.33  4.89
# 44   95.17   9.00  5.22
# 45   90.63   5.08  6.02
# 46  105.09  11.18  6.64
# 47  120.29  10.18  7.50
# 48  121.83  11.03  7.11
# 49  108.58   5.67  7.19
# 50  121.60   9.58  9.19
# 51  119.49  10.37  8.04
# 52  144.17  17.33  9.85
# 53  128.90   4.10  9.58
# 54   42.02   4.30  2.74
# 55   40.35   2.70  3.27>

# %% [markdown]
# # I Model_1 Sales with Advt

# %% [markdown]
# we are building the model only on advt as per client requirment future 4Q sales predictions
# budget allocating
# 2020 june 17L
# 2020 sep 11L
# 2020 dec 9L
# 2021 march 16L

# %% [markdown]
# # 1.1 Model_1(direct)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
model=ols('Sales~Advt',data=sales).fit()
model1=sm.stats.anova_lm(model)
model1
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.531
# Model:                            OLS   Adj. R-squared:                  0.523
# Method:                 Least Squares   F-statistic:                     61.20
# Date:                Thu, 05 Jan 2023   Prob (F-statistic):           1.90e-10
# Time:                        12:15:41   Log-Likelihood:                -253.17
# No. Observations:                  56   AIC:                             510.3
# Df Residuals:                      54   BIC:                             514.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     40.3461      6.913      5.836      0.000      26.487      54.205
# Advt           6.4923      0.830      7.823      0.000       4.828       8.156
# ==============================================================================
# Omnibus:                       11.670   Durbin-Watson:                   1.843
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               11.765
# Skew:                           1.032   Prob(JB):                      0.00279
# Kurtosis:                       3.884   Cond. No.                         19.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
pre1=model.predict()
pre1
# Out:
# array([ 68.26296594,  57.87529514,  70.14573128,  69.82111656,
#         97.93275067,  60.92667344,  88.64876989,  94.42691177,
#         98.77674892,  73.32695546, 112.92995038, 106.43765613,
#        111.95610625,  77.15740907, 102.54227958, 107.67119204,
#        152.85756002,  66.96450709,  68.26296594,  57.87529514,
#         70.14573128,  69.82111656,  97.93275067,  60.92667344,
#         88.64876989,  94.42691177,  98.77674892,  73.32695546,
#        112.92995038, 106.43765613, 111.95610625,  77.15740907,
#        102.54227958, 107.67119204, 152.85756002,  66.96450709,
#         68.26296594,  57.87529514,  70.14573128,  69.82111656,
#         97.93275067,  60.92667344,  88.64876989,  94.42691177,
#         98.77674892,  73.32695546, 112.92995038, 106.43765613,
#        111.95610625,  77.15740907, 102.54227958, 107.67119204,
#        152.85756002,  66.96450709,  68.26296594,  57.87529514])

# %%
res1=sales['Sales'].values-pre1
res1
# Out:
# array([-26.24296594, -17.52529514, -23.25573128, -15.72111656,
#        -27.80275067,   2.44332656, -14.63876989,  -7.79691177,
#         -3.60674892,  17.30304454,  -7.83995038,  13.85234387,
#          9.87389375,  31.42259093,  19.05772042,  11.81880796,
#         -8.68756002,  61.93549291, -26.24296594, -17.52529514,
#        -23.25573128, -15.72111656, -27.80275067,   2.44332656,
#        -14.63876989,  -7.79691177,  -3.60674892,  17.30304454,
#         -7.83995038,  13.85234387,   9.87389375,  31.42259093,
#         19.05772042,  11.81880796,  -8.68756002,  61.93549291,
#        -26.24296594, -17.52529514, -23.25573128, -15.72111656,
#        -27.80275067,   2.44332656, -14.63876989,  -7.79691177,
#         -3.60674892,  17.30304454,  -7.83995038,  13.85234387,
#          9.87389375,  31.42259093,  19.05772042,  11.81880796,
#         -8.68756002,  61.93549291, -26.24296594, -17.52529514])

# %%
pre_1=pd.DataFrame(pre1,columns=["pre1"])
pre_1
# Out:
#            pre1
# 0    108.934987
# 1     86.971959
# 2    102.445911
# 3     99.783725
# 4    135.723227
# 5    193.625757
# 6    196.371135
# 7    151.446759
# 8     81.647588
# 9    132.561882
# 10   151.862725
# 11   145.373648
# 12    90.882043
# 13    68.835822
# 14   239.298873
# 15   138.718185
# 16    93.377842
# 17    96.289607
# 18    83.561034
# 19   138.718185
# 20   100.366078
# 21   162.261886
# 22    90.466077
# 23   125.906419
# 24   155.772810
# 25   139.550118
# 26   162.178693
# 27    72.080360
# 28   154.275330
# 29   132.561882
# ..          ...
# 191  155.772810
# 192  164.924072
# 193   88.552631
# 194   91.048430
# 195  128.402217
# 196   96.289607
# 197  139.550118
# 198   94.126582
# 199   86.389606
# 200  193.625757
# 201  167.419870
# 202  100.449272
# 203  132.145915
# 204  277.401400
# 205  194.707269
# 206  134.308941
# 207  137.137513
# 208  139.550118
# 209  137.137513
# 210  127.154318
# 211   66.173636
# 212  145.540035
# 213  213.259373
# 214  179.982057
# 215  115.756837
# 216   90.050111
# 217   71.913973
# 218   98.619019
# 219   65.924056
# 220  186.554327
#
# [221 rows x 1 columns]

# %%
res_1=pd.DataFrame(res1,columns=["res1"])
res_1
# Out:
#           res1
# 0    35.985013
# 1    -5.081959
# 2   -27.465911
# 3     5.126275
# 4    81.436773
# 5   -11.565757
# 6    -6.041135
# 7     4.933241
# 8   -33.537588
# 9    31.218118
# 10   46.657275
# 11   77.576352
# 12  -31.712043
# 13   -9.925822
# 14   -2.618873
# 15  -14.998185
# 16   18.092158
# 17   21.530393
# 18   17.768966
# 19  -14.998185
# 20  -44.296078
# 21  -25.641886
# 22  -20.136077
# 23   55.353581
# 24  -21.392810
# 25   79.529882
# 26   10.831307
# 27   -1.500360
# 28   -4.425330
# 29   31.218118
# ..         ...
# 191 -26.512810
# 192  -7.894072
# 193  20.027369
# 194 -30.088430
# 195  80.717783
# 196  21.530393
# 197  79.529882
# 198  32.613418
# 199 -30.079606
# 200 -11.565757
# 201 -12.679870
# 202 -31.119272
# 203 -45.885915
# 204 -53.121400
# 205  24.882731
# 206  -1.218941
# 207  83.222487
# 208   1.109882
# 209  83.222487
# 210  56.775682
# 211 -35.693636
# 212   2.419965
# 213  30.870627
# 214  -6.722057
# 215 -31.736837
# 216 -28.190111
# 217 -34.423973
# 218 -31.429019
# 219 -30.754056
# 220 -15.994327
#
# [221 rows x 1 columns]

# %%
zscore1=pd.DataFrame(zscore(res1),columns=['zscore1'])
zscore1
# Out:
#       zscore1
# 0    1.100647
# 1   -0.155438
# 2   -0.840079
# 3    0.156794
# 4    2.490846
# 5   -0.353753
# 6   -0.184776
# 7    0.150889
# 8   -1.025789
# 9    0.954845
# 10   1.427071
# 11   2.372770
# 12  -0.969953
# 13  -0.303594
# 14  -0.080102
# 15  -0.458738
# 16   0.553371
# 17   0.658534
# 18   0.543486
# 19  -0.458738
# 20  -1.354851
# 21  -0.784289
# 22  -0.615887
# 23   1.693059
# 24  -0.654326
# 25   2.432521
# 26   0.331289
# 27  -0.045890
# 28  -0.135354
# 29   0.954845
# ..        ...
# 191 -0.810928
# 192 -0.241450
# 193  0.612562
# 194 -0.920292
# 195  2.468855
# 196  0.658534
# 197  2.432521
# 198  0.997522
# 199 -0.920023
# 200 -0.353753
# 201 -0.387830
# 202 -0.951822
# 203 -1.403478
# 204 -1.624785
# 205  0.761070
# 206 -0.037283
# 207  2.545464
# 208  0.033947
# 209  2.545464
# 210  1.736556
# 211 -1.091735
# 212  0.074018
# 213  0.944217
# 214 -0.205603
# 215 -0.970711
# 216 -0.862230
# 217 -1.052900
# 218 -0.961296
# 219 -0.940651
# 220 -0.489207
#
# [221 rows x 1 columns]

# %%
sales1=pd.concat([sales,pre_1,res_1,zscore1],axis=1)
sales1
sales_1=pd.DataFrame(sales1)
sales_1
# Out:
#       Sales   Advt     PC        pre1       res1   zscore1
# 0    144.92   8.12   9.63  108.934987  35.985013  1.100647
# 1     81.89   5.48   6.64   86.971959  -5.081959 -0.155438
# 2     74.98   7.34   5.28  102.445911 -27.465911 -0.840079
# 3    104.91   7.02   8.50   99.783725   5.126275  0.156794
# 4    217.16  11.34  14.38  135.723227  81.436773  2.490846
# 5    182.06  18.30  10.18  193.625757 -11.565757 -0.353753
# 6    190.33  18.63  13.39  196.371135  -6.041135 -0.184776
# 7    156.38  13.23   9.75  151.446759   4.933241  0.150889
# 8     48.11   4.84   2.69   81.647588 -33.537588 -1.025789
# 9    163.78  10.96  13.27  132.561882  31.218118  0.954845
# 10   198.52  13.28  16.09  151.862725  46.657275  1.427071
# 11   222.95  12.50  14.81  145.373648  77.576352  2.372770
# 12    59.17   5.95   3.31   90.882043 -31.712043 -0.969953
# 13    58.91   3.30   3.91   68.835822  -9.925822 -0.303594
# 14   236.68  23.79  13.24  239.298873  -2.618873 -0.080102
# 15   123.72  11.70   6.79  138.718185 -14.998185 -0.458738
# 16   111.47   6.25   7.40   93.377842  18.092158  0.553371
# 17   117.82   6.60   7.83   96.289607  21.530393  0.658534
# 18   101.33   5.07   6.56   83.561034  17.768966  0.543486
# 19   123.72  11.70   6.79  138.718185 -14.998185 -0.458738
# 20    56.07   7.09   3.08  100.366078 -44.296078 -1.354851
# 21   136.62  14.53   8.63  162.261886 -25.641886 -0.784289
# 22    70.33   5.90   4.43   90.466077 -20.136077 -0.615887
# 23   181.26  10.16  12.04  125.906419  55.353581  1.693059
# 24   134.38  13.75   8.76  155.772810 -21.392810 -0.654326
# 25   219.08  11.80  13.12  139.550118  79.529882  2.432521
# 26   173.01  14.52  10.91  162.178693  10.831307  0.331289
# 27    70.58   3.69   4.67   72.080360  -1.500360 -0.045890
# 28   149.85  13.57   8.75  154.275330  -4.425330 -0.135354
# 29   163.78  10.96  13.27  132.561882  31.218118  0.954845
# ..      ...    ...    ...         ...        ...       ...
# 191  129.26  13.75   8.17  155.772810 -26.512810 -0.810928
# 192  157.03  14.85   8.61  164.924072  -7.894072 -0.241450
# 193  108.58   5.67   7.19   88.552631  20.027369  0.612562
# 194   60.96   5.97   4.29   91.048430 -30.088430 -0.920292
# 195  209.12  10.46  13.53  128.402217  80.717783  2.468855
# 196  117.82   6.60   7.83   96.289607  21.530393  0.658534
# 197  219.08  11.80  13.12  139.550118  79.529882  2.432521
# 198  126.74   6.34   8.20   94.126582  32.613418  0.997522
# 199   56.31   5.41   3.18   86.389606 -30.079606 -0.920023
# 200  182.06  18.30  10.18  193.625757 -11.565757 -0.353753
# 201  154.74  15.15  10.89  167.419870 -12.679870 -0.387830
# 202   69.33   7.10   4.52  100.449272 -31.119272 -0.951822
# 203   86.26  10.91   4.74  132.145915 -45.885915 -1.403478
# 204  224.28  28.37  12.31  277.401400 -53.121400 -1.624785
# 205  219.59  18.43  13.84  194.707269  24.882731  0.761070
# 206  133.09  11.17   8.39  134.308941  -1.218941 -0.037283
# 207  220.36  11.51  14.59  137.137513  83.222487  2.545464
# 208  140.66  11.80   8.87  139.550118   1.109882  0.033947
# 209  220.36  11.51  14.59  137.137513  83.222487  2.545464
# 210  183.93  10.31  12.22  127.154318  56.775682  1.736556
# 211   30.48   2.98   2.15   66.173636 -35.693636 -1.091735
# 212  147.96  12.52   9.23  145.540035   2.419965  0.074018
# 213  244.13  20.66  15.22  213.259373  30.870627  0.944217
# 214  173.26  16.66   9.78  179.982057  -6.722057 -0.205603
# 215   84.02   8.94   5.31  115.756837 -31.736837 -0.970711
# 216   61.86   5.85   3.39   90.050111 -28.190111 -0.862230
# 217   37.49   3.67   2.64   71.913973 -34.423973 -1.052900
# 218   67.19   6.88   4.38   98.619019 -31.429019 -0.961296
# 219   35.17   2.95   2.22   65.924056 -30.754056 -0.940651
# 220  170.56  17.45  11.12  186.554327 -15.994327 -0.489207
#
# [221 rows x 6 columns]

# %%
zscore1[zscore1['zscore1']>1.96]
# Out:
#       zscore1
# 4    2.490846
# 11   2.372770
# 25   2.432521
# 100  2.490846
# 105  2.488057
# 125  2.468855
# 161  2.352694
# 165  2.488057
# 169  2.372770
# 195  2.468855
# 197  2.432521
# 207  2.545464
# 209  2.545464

# %%
zscore1[zscore1['zscore1']<-1.96]
# Out:
# Empty DataFrame
# Columns: [zscore1]
# Index: []

# %% [markdown]
# # 1.2 Model_1 Applying (Dummy)

# %% [markdown]
# We are applying dummy,where the value is above 1.96 as 1 and below 1.96 as 0 because those are the outliers to improve the model dummy variable is used.

# %%
a=sales_1.copy()
for i in range(0,len(a)):
    if(np.any(a['zscore1'].values[i]>1.96)):
        a['zscore1'].values[i]=0
    else:
        a['zscore1'].values[i]=1
        test=a['zscore1']
        test
sales_1['dummy']=test
sales_1
# Out:
# 203   86.26  10.91   4.74  132.145915 -45.885915 -1.403478    1.0
# 204  224.28  28.37  12.31  277.401400 -53.121400 -1.624785    1.0
# 205  219.59  18.43  13.84  194.707269  24.882731  0.761070    1.0
# 206  133.09  11.17   8.39  134.308941  -1.218941 -0.037283    1.0
# 207  220.36  11.51  14.59  137.137513  83.222487  2.545464    0.0
# 208  140.66  11.80   8.87  139.550118   1.109882  0.033947    1.0
# 209  220.36  11.51  14.59  137.137513  83.222487  2.545464    0.0
# 210  183.93  10.31  12.22  127.154318  56.775682  1.736556    1.0
# 211   30.48   2.98   2.15   66.173636 -35.693636 -1.091735    1.0
# 212  147.96  12.52   9.23  145.540035   2.419965  0.074018    1.0
# 213  244.13  20.66  15.22  213.259373  30.870627  0.944217    1.0
# 214  173.26  16.66   9.78  179.982057  -6.722057 -0.205603    1.0
# 215   84.02   8.94   5.31  115.756837 -31.736837 -0.970711    1.0
# 216   61.86   5.85   3.39   90.050111 -28.190111 -0.862230    1.0
# 217   37.49   3.67   2.64   71.913973 -34.423973 -1.052900    1.0
# 218   67.19   6.88   4.38   98.619019 -31.429019 -0.961296    1.0
# 219   35.17   2.95   2.22   65.924056 -30.754056 -0.940651    1.0
# 220  170.56  17.45  11.12  186.554327 -15.994327 -0.489207    1.0
#
# [221 rows x 7 columns]

# %%
x=sales_1[["Advt","dummy"]]
y=sales_1["Sales"]
y
# Out:
# 0      144.92
# 1       81.89
# 2       74.98
# 3      104.91
# 4      217.16
# 5      182.06
# 6      190.33
# 7      156.38
# 8       48.11
# 9      163.78
# 10     198.52
# 11     222.95
# 12      59.17
# 13      58.91
# 14     236.68
# 15     123.72
# 16     111.47
# 17     117.82
# 18     101.33
# 19     123.72
# 20      56.07
# 21     136.62
# 22      70.33
# 23     181.26
# 24     134.38
# 25     219.08
# 26     173.01
# 27      70.58
# 28     149.85
# 29     163.78
#         ...
# 191    129.26
# 192    157.03
# 193    108.58
# 194     60.96
# 195    209.12
# 196    117.82
# 197    219.08
# 198    126.74
# 199     56.31
# 200    182.06
# 201    154.74
# 202     69.33
# 203     86.26
# 204    224.28
# 205    219.59
# 206    133.09
# 207    220.36
# 208    140.66
# 209    220.36
# 210    183.93
# 211     30.48
# 212    147.96
# 213    244.13
# 214    173.26
# 215     84.02
# 216     61.86
# 217     37.49
# 218     67.19
# 219     35.17
# 220    170.56
# Name: Sales, Length: 221, dtype: float64

# %%
plt.scatter(y,res1)
plt.xlabel("res_adv")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20,random_state=0)

# %%
x_train
# Out:
#       Advt  dummy
# 33   16.66    1.0
# 101  20.49    1.0
# 146   2.70    1.0
# 197  11.80    0.0
# 134   5.77    1.0
# 201  15.15    1.0
# 186   6.64    1.0
# 215   8.94    1.0
# 16    6.25    1.0
# 92   14.98    1.0
# 107   7.20    1.0
# 130   5.90    1.0
# 22    5.90    1.0
# 200  18.30    1.0
# 45   17.88    1.0
# 208  11.80    1.0
# 4    11.34    0.0
# 137  11.90    1.0
# 154   3.63    1.0
# 61   11.90    1.0
# 52    4.46    1.0
# 26   14.52    1.0
# 136   8.91    1.0
# 40    7.57    1.0
# 13    3.30    1.0
# 159  10.25    1.0
# 182  18.43    1.0
# 24   13.75    1.0
# 30   23.06    1.0
# 60   11.18    1.0
# ..     ...    ...
# 79    8.33    1.0
# 115  12.28    1.0
# 148  18.00    1.0
# 213  20.66    1.0
# 72    8.14    1.0
# 77   13.74    1.0
# 25   11.80    0.0
# 165  11.97    0.0
# 81    9.36    1.0
# 207  11.51    0.0
# 174   9.67    1.0
# 209  11.51    0.0
# 39    8.38    1.0
# 193   5.67    1.0
# 58   14.39    1.0
# 140  18.00    1.0
# 88    9.15    1.0
# 70   14.19    1.0
# 87   11.93    1.0
# 36   14.34    1.0
# 21   14.53    1.0
# 211   2.98    1.0
# 9    10.96    1.0
# 103  16.80    1.0
# 195  10.46    0.0
# 67    7.26    1.0
# 192  14.85    1.0
# 117   6.97    1.0
# 47   17.64    1.0
# 172   5.59    1.0
#
# [176 rows x 2 columns]

# %%
y_train
# Out:
# 33     173.26
# 101    213.11
# 146     40.35
# 197    219.08
# 134     45.58
# 201    154.74
# 186     99.26
# 215     84.02
# 16     111.47
# 92     178.53
# 107     76.09
# 130    109.54
# 22      70.33
# 200    182.06
# 45     168.04
# 208    140.66
# 4      217.16
# 137    118.34
# 154     43.25
# 61     118.34
# 52      66.58
# 26     173.01
# 136    133.16
# 40      77.37
# 13      58.91
# 159    106.55
# 182    219.59
# 24     134.38
# 30     182.34
# 60     105.09
#         ...
# 79      86.63
# 115    122.12
# 148    190.34
# 213    244.13
# 72      96.17
# 77     142.94
# 25     219.08
# 165    222.31
# 81     179.16
# 207    220.36
# 174     96.21
# 209    220.36
# 39     149.54
# 193    108.58
# 58     152.18
# 140    142.33
# 88      91.03
# 70     138.67
# 87     121.91
# 36     158.38
# 21     136.62
# 211     30.48
# 9      163.78
# 103    198.48
# 195    209.12
# 67      86.51
# 192    157.03
# 117    133.55
# 47     194.81
# 172     54.63
# Name: Sales, Length: 176, dtype: float64

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
x_train1=sm.add_constant(x_train)
model=sm.OLS( y_train,x_train1).fit()
print(model.summary())
ols = linear_model.LinearRegression()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.807
# Method:                 Least Squares   F-statistic:                     366.1
# Date:                Wed, 28 Sep 2022   Prob (F-statistic):           6.74e-63
# Time:                        09:44:02   Log-Likelihood:                -812.34
# No. Observations:                 176   AIC:                             1631.
# Df Residuals:                     173   BIC:                             1640.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        121.8644      8.109     15.028      0.000     105.859     137.870
# Advt           8.3282      0.341     24.448      0.000       7.656       9.001
# dummy        -85.2174      7.375    -11.555      0.000     -99.773     -70.661
# ==============================================================================
# Omnibus:                       10.840   Durbin-Watson:                   2.199
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.643
# Skew:                           0.630   Prob(JB):                      0.00296
# Kurtosis:                       2.964   Cond. No.                         71.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\91707\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
regr = linear_model.LinearRegression()
regr.fit(x_train,y_train)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#
# 19     123.72
# 20      56.07
# 21     136.62
# 22      70.33
# 23     181.26
# 24     134.38
# 25     219.08
# 26     173.01
# 27      70.58
# 28     149.85
# 29     163.78
#         ...
# 191    129.26
# 192    157.03
# 193    108.58
# 194     60.96
# 195    209.12
# 196    117.82
# 197    219.08
# 198    126.74
# 199     56.31
# 200    182.06
# 201    154.74
# 202     69.33
# 203     86.26
# 204    224.28
# 205    219.59
# 206    133.09
# 207    220.36
# 208    140.66
# 209    220.36
# 210    183.93
# 211     30.48
# 212    147.96
# 213    244.13
# 214    173.26
# 215     84.02
# 216     61.86
# 217     37.49
# 218     67.19
# 219     35.17
# 220    170.56
# Name: Sales, Length: 221, dtype: float64

# %%
plt.scatter(y,res1)
plt.xlabel("res_adv")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20,random_state=0)

# %%
x_train
# Out:
#       Advt  sqr_Advt
# 33   16.66  277.5556
# 101  20.49  419.8401
# 146   2.70    7.2900
# 197  11.80  139.2400
# 134   5.77   33.2929
# 201  15.15  229.5225
# 186   6.64   44.0896
# 215   8.94   79.9236
# 16    6.25   39.0625
# 92   14.98  224.4004
# 107   7.20   51.8400
# 130   5.90   34.8100
# 22    5.90   34.8100
# 200  18.30  334.8900
# 45   17.88  319.6944
# 208  11.80  139.2400
# 4    11.34  128.5956
# 137  11.90  141.6100
# 154   3.63   13.1769
# 61   11.90  141.6100
# 52    4.46   19.8916
# 26   14.52  210.8304
# 136   8.91   79.3881
# 40    7.57   57.3049
# 13    3.30   10.8900
# 159  10.25  105.0625
# 182  18.43  339.6649
# 24   13.75  189.0625
# 30   23.06  531.7636
# 60   11.18  124.9924
# ..     ...       ...
# 79    8.33   69.3889
# 115  12.28  150.7984
# 148  18.00  324.0000
# 213  20.66  426.8356
# 72    8.14   66.2596
# 77   13.74  188.7876
# 25   11.80  139.2400
# 165  11.97  143.2809
# 81    9.36   87.6096
# 207  11.51  132.4801
# 174   9.67   93.5089
# 209  11.51  132.4801
# 39    8.38   70.2244
# 193   5.67   32.1489
# 58   14.39  207.0721
# 140  18.00  324.0000
# 88    9.15   83.7225
# 70   14.19  201.3561
# 87   11.93  142.3249
# 36   14.34  205.6356
# 21   14.53  211.1209
# 211   2.98    8.8804
# 9    10.96  120.1216
# 103  16.80  282.2400
# 195  10.46  109.4116
# 67    7.26   52.7076
# 192  14.85  220.5225
# 117   6.97   48.5809
# 47   17.64  311.1696
# 172   5.59   31.2481
#
# [176 rows x 2 columns]

# %%
y_train
# Out:
# 33     173.26
# 101    213.11
# 146     40.35
# 197    219.08
# 134     45.58
# 201    154.74
# 186     99.26
# 215     84.02
# 16     111.47
# 92     178.53
# 107     76.09
# 130    109.54
# 22      70.33
# 200    182.06
# 45     168.04
# 208    140.66
# 4      217.16
# 137    118.34
# 154     43.25
# 61     118.34
# 52      66.58
# 26     173.01
# 136    133.16
# 40      77.37
# 13      58.91
# 159    106.55
# 182    219.59
# 24     134.38
# 30     182.34
# 60     105.09
#         ...
# 79      86.63
# 115    122.12
# 148    190.34
# 213    244.13
# 72      96.17
# 77     142.94
# 25     219.08
# 165    222.31
# 81     179.16
# 207    220.36
# 174     96.21
# 209    220.36
# 39     149.54
# 193    108.58
# 58     152.18
# 140    142.33
# 88      91.03
# 70     138.67
# 87     121.91
# 36     158.38
# 21     136.62
# 211     30.48
# 9      163.78
# 103    198.48
# 195    209.12
# 67      86.51
# 192    157.03
# 117    133.55
# 47     194.81
# 172     54.63
# Name: Sales, Length: 176, dtype: float64

# %%
x_test
# Out:
#       Advt  sqr_Advt
# 129  20.36  414.5296
# 202   7.10   50.4100
# 138   5.65   31.9225
# 66   18.45  340.4025
# 180   2.06    4.2436
# 145   4.72   22.2784
# 44    3.90   15.2100
# 71   14.18  201.0724
# 64    7.80   60.8400
# 8     4.84   23.4256
# 83    7.17   51.4089
# 37   18.00  324.0000
# 5    18.30  334.8900
# 169  12.50  156.2500
# 63   10.80  116.6400
# 198   6.34   40.1956
# 162  14.68  215.5024
# 203  10.91  119.0281
# 173  22.58  509.8564
# 89   22.14  490.1796
# 108   3.44   11.8336
# 126  10.16  103.2256
# 123  14.39  207.0721
# 74    4.54   20.6116
# 76   29.27  856.7329
# 12    5.95   35.4025
# 156  22.14  490.1796
# 158   2.80    7.8400
# 122  22.06  486.6436
# 143   7.44   55.3536
# 55    9.07   82.2649
# 144   9.07   82.2649
# 97   17.88  319.6944
# 217   3.67   13.4689
# 18    5.07   25.7049
# 15   11.70  136.8900
# 150   9.74   94.8676
# 7    13.23  175.0329
# 75    1.76    3.0976
# 160   4.12   16.9744
# 96   10.58  111.9364
# 141  13.32  177.4224
# 90    9.00   81.0000
# 104   3.32   11.0224
# 204  28.37  804.8569

# %%
y_test
# Out:
# 129    240.58
# 202     69.33
# 138     57.67
# 66     173.40
# 180     41.19
# 145     87.58
# 44      77.95
# 71     112.14
# 64     155.89
# 8       48.11
# 83      79.19
# 37     190.34
# 5      182.06
# 169    222.95
# 63     161.40
# 198    126.74
# 162    149.95
# 203     86.26
# 173    230.70
# 89     234.12
# 108     33.59
# 126    181.26
# 123    152.18
# 74      54.10
# 76     231.43
# 12      59.17
# 156    234.12
# 158     27.31
# 122    243.66
# 143     74.01
# 55     173.62
# 144    173.62
# 97     168.04
# 217     37.49
# 18     101.33
# 15     123.72
# 150    180.74
# 7      156.38
# 75      26.23
# 160     82.38
# 96     103.37
# 141    138.52
# 90      95.17
# 104     49.63
# 204    224.28
# Name: Sales, dtype: float64

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
x_train1=sm.add_constant(x_train)
model=sm.OLS( y_train,x_train1).fit()
print(model.summary())
ols = linear_model.LinearRegression()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.678
# Method:                 Least Squares   F-statistic:                     185.3
# Date:                Wed, 28 Sep 2022   Prob (F-statistic):           9.84e-44
# Time:                        09:44:11   Log-Likelihood:                -857.23
# No. Observations:                 176   AIC:                             1720.
# Df Residuals:                     173   BIC:                             1730.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.6923     11.289      0.859      0.392     -12.589      31.974
# Advt          14.7949      1.993      7.423      0.000      10.861      18.729
# sqr_Advt      -0.2562      0.077     -3.323      0.001      -0.408      -0.104
# ==============================================================================
# Omnibus:                       13.121   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.620
# Skew:                           0.694   Prob(JB):                     0.000669
# Kurtosis:                       2.746   Cond. No.                     1.02e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.02e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\91707\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
regr = linear_model.LinearRegression()
regr.fit(x_train,y_train)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  9.692296679181155
# Coefficients:
#  [14.79494067 -0.25624488]

# %%
y_pred = regr.predict(x_test)
y_pred
# Out:
# array([204.69620216, 101.81907115,  85.10373436, 195.43255513,
#         39.08247369,  73.81569076,  63.4950807 , 167.96078287,
#        109.50289555,  75.29711951, 102.59875399, 192.97788843,
#        194.62586392, 154.59079294, 139.5892534 ,  93.19230392,
#        171.66063962, 140.60475848, 213.11396627, 211.64627158,
#         57.5545932 , 133.55786265, 169.53032802,  71.5797104 ,
#        223.20679313,  88.65048438, 211.64627158,  49.10917071,
#        211.36875821, 105.58257881, 122.80244933, 122.80244933,
#        192.3057835 ,  60.5383923 ,  78.11589692, 147.71574123,
#        129.48568226, 160.57807772,  34.93764812,  66.29784918,
#        137.53963986, 161.29732525, 122.09092762,  55.98706616,
#        223.18430579])

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 26.134786342713575
# Mean Squared Error: 921.3613221753258
# Root Mean Squared Error: 30.35393421247608

# %% [markdown]
# # 1.4 Model_1 Applying(Square root)

# %%
sales_1["squareRoot_Advt"]=sales1["Advt"]**(1/2)
sales_1
# Out:
#       Sales   Advt     PC        pre1       res1   zscore1  dummy  sqr_Advt  \
# 0    144.92   8.12   9.63  108.934987  35.985013  1.100647    1.0   65.9344
# 1     81.89   5.48   6.64   86.971959  -5.081959 -0.155438    1.0   30.0304
# 2     74.98   7.34   5.28  102.445911 -27.465911 -0.840079    1.0   53.8756
# 3    104.91   7.02   8.50   99.783725   5.126275  0.156794    1.0   49.2804
# 4    217.16  11.34  14.38  135.723227  81.436773  2.490846    0.0  128.5956
# 5    182.06  18.30  10.18  193.625757 -11.565757 -0.353753    1.0  334.8900
# 6    190.33  18.63  13.39  196.371135  -6.041135 -0.184776    1.0  347.0769
# 7    156.38  13.23   9.75  151.446759   4.933241  0.150889    1.0  175.0329
# 8     48.11   4.84   2.69   81.647588 -33.537588 -1.025789    1.0   23.4256
# 9    163.78  10.96  13.27  132.561882  31.218118  0.954845    1.0  120.1216
# 10   198.52  13.28  16.09  151.862725  46.657275  1.427071    1.0  176.3584
# 11   222.95  12.50  14.81  145.373648  77.576352  2.372770    0.0  156.2500
# 12    59.17   5.95   3.31   90.882043 -31.712043 -0.969953    1.0   35.4025
# 13    58.91   3.30   3.91   68.835822  -9.925822 -0.303594    1.0   10.8900
# 14   236.68  23.79  13.24  239.298873  -2.618873 -0.080102    1.0  565.9641
# 15   123.72  11.70   6.79  138.718185 -14.998185 -0.458738    1.0  136.8900
# 16   111.47   6.25   7.40   93.377842  18.092158  0.553371    1.0   39.0625
# 17   117.82   6.60   7.83   96.289607  21.530393  0.658534    1.0   43.5600
# 18   101.33   5.07   6.56   83.561034  17.768966  0.543486    1.0   25.7049
# 19   123.72  11.70   6.79  138.718185 -14.998185 -0.458738    1.0  136.8900
# 20    56.07   7.09   3.08  100.366078 -44.296078 -1.354851    1.0   50.2681
# 21   136.62  14.53   8.63  162.261886 -25.641886 -0.784289    1.0  211.1209
# 220  170.56  17.45  11.12  186.554327 -15.994327 -0.489207    1.0  304.5025
#
#      squareRoot_Advt
# 0           2.849561
# 1           2.340940
# 2           2.709243
# 3           2.649528
# 4           3.367492
# 5           4.277850
# 6           4.316248
# 7           3.637307
# 8           2.200000
# 9           3.310589
# 10          3.644173
# 11          3.535534
# 12          2.439262
# 13          1.816590
# 14          4.877499
# 15          3.420526
# 16          2.500000
# 17          2.569047
# 18          2.251666
# 19          3.420526
# 20          2.662705
# 21          3.811824
# 22          2.428992
# 23          3.187475
# 24          3.708099
# 25          3.435113
# 26          3.810512
# 27          1.920937
# 28          3.683748
# 29          3.310589
# ..               ...
# 191         3.708099
# 192         3.853570
# 193         2.381176
# 194         2.443358
# 195         3.234192
# 196         2.569047
# 197         3.435113
# 198         2.517936
# 199         2.325941
# 200         4.277850
# 201         3.892300
# 202         2.664583
# 203         3.303029
# 204         5.326350
# 205         4.293018
# 206         3.342155
# 207         3.392639
# 208         3.435113
# 209         3.392639
# 210         3.210919
# 211         1.726268
# 212         3.538361
# 213         4.545327
# 214         4.081666
# 215         2.989983
# 216         2.418677
# 217         1.915724
# 218         2.622975
# 219         1.717556
# 220         4.177320
#
# [221 rows x 9 columns]

# %%
x_ADVT=sales_1[["Advt","squareRoot_Advt"]]
y_ADVT=sales_1["Sales"]
y_ADVT
# Out:
# 0      144.92
# 1       81.89
# 2       74.98
# 3      104.91
# 4      217.16
# 5      182.06
# 6      190.33
# 7      156.38
# 8       48.11
# 9      163.78
# 10     198.52
# 11     222.95
# 12      59.17
# 13      58.91
# 14     236.68
# 15     123.72
# 16     111.47
# 17     117.82
# 18     101.33
# 19     123.72
# 20      56.07
# 21     136.62
# 22      70.33
# 23     181.26
# 24     134.38
# 25     219.08
# 26     173.01
# 27      70.58
# 28     149.85
# 29     163.78
#         ...
# 191    129.26
# 192    157.03
# 193    108.58
# 194     60.96
# 195    209.12
# 196    117.82
# 197    219.08
# 198    126.74
# 199     56.31
# 200    182.06
# 201    154.74
# 202     69.33
# 203     86.26
# 204    224.28
# 205    219.59
# 206    133.09
# 207    220.36
# 208    140.66
# 209    220.36
# 210    183.93
# 211     30.48
# 212    147.96
# 213    244.13
# 214    173.26
# 215     84.02
# 216     61.86
# 217     37.49
# 218     67.19
# 219     35.17
# 220    170.56
# Name: Sales, Length: 221, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x_ADVT, y_ADVT, test_size=0.20,random_state=0)

# %%
x_train
# Out:
#       Advt  squareRoot_Advt
# 33   16.66         4.081666
# 101  20.49         4.526588
# 146   2.70         1.643168
# 197  11.80         3.435113
# 134   5.77         2.402082
# 201  15.15         3.892300
# 186   6.64         2.576820
# 215   8.94         2.989983
# 16    6.25         2.500000
# 92   14.98         3.870400
# 107   7.20         2.683282
# 130   5.90         2.428992
# 22    5.90         2.428992
# 200  18.30         4.277850
# 45   17.88         4.228475
# 208  11.80         3.435113
# 4    11.34         3.367492
# 137  11.90         3.449638
# 154   3.63         1.905256
# 61   11.90         3.449638
# 52    4.46         2.111871
# 26   14.52         3.810512
# 136   8.91         2.984962
# 40    7.57         2.751363
# 141  13.32         3.649658
# 90    9.00         3.000000
# 104   3.32         1.822087
# 204  28.37         5.326350

# %%
y_test
# Out:
# 129    240.58
# 202     69.33
# 138     57.67
# 66     173.40
# 180     41.19
# 145     87.58
# 44      77.95
# 71     112.14
# 64     155.89
# 8       48.11
# 83      79.19
# 37     190.34
# 5      182.06
# 169    222.95
# 63     161.40
# 198    126.74
# 162    149.95
# 203     86.26
# 173    230.70
# 89     234.12
# 108     33.59
# 126    181.26
# 123    152.18
# 74      54.10
# 76     231.43
# 12      59.17
# 156    234.12
# 158     27.31
# 122    243.66
# 143     74.01
# 55     173.62
# 144    173.62
# 97     168.04
# 217     37.49
# 18     101.33
# 15     123.72
# 150    180.74
# 7      156.38
# 75      26.23
# 160     82.38
# 96     103.37
# 141    138.52
# 90      95.17
# 104     49.63
# 204    224.28
# Name: Sales, dtype: float64

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
x_train1=sm.add_constant(x_train)
model=sm.OLS( y_train,x_train1).fit()
print(model.summary())
ols = linear_model.LinearRegression()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.685
# Model:                            OLS   Adj. R-squared:                  0.682
# Method:                 Least Squares   F-statistic:                     188.3
# Date:                Wed, 28 Sep 2022   Prob (F-statistic):           3.72e-44
# Time:                        09:44:14   Log-Likelihood:                -856.24
# No. Observations:                 176   AIC:                             1718.
# Df Residuals:                     173   BIC:                             1728.
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             -78.7491     33.886     -2.324      0.021    -145.633     -11.866
# Advt               -3.2312      3.223     -1.003      0.317      -9.592       3.130
# squareRoot_Advt    77.2693     21.330      3.623      0.000      35.169     119.370
# ==============================================================================
# Omnibus:                       11.767   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.901
# Skew:                           0.652   Prob(JB):                      0.00158
# Kurtosis:                       2.752   Cond. No.                         219.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\91707\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
regr = linear_model.LinearRegression()
regr.fit(x_train,y_train)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  -78.74914774205533
# Coefficients:
#  [-3.23121763 77.26927884]

# %%
y_pred = regr.predict(x_test)
y_pred

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %% [markdown]
# # 1.5 Model_1 Applying(log10)

# %%
sales_1['log_Advt'] = np.log10(sales_1['Advt'])
sales_1

# %%
x_advt=sales_1[["Advt","log_Advt"]]
y_advt=sales_1["Sales"]
y_advt

# %%
x_train, x_test, y_train, y_test = train_test_split(x_advt, y_advt, test_size=0.20,random_state=0)

# %%
x_train

# %%
y_train

# %%
x_test

# %%
y_test

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
x_train1=sm.add_constant(x_train)
model=sm.OLS( y_train,x_train1).fit()
print(model.summary())
ols = linear_model.LinearRegression()

# %%
regr = linear_model.LinearRegression()
regr.fit(x_train,y_train)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# %%
y_pred = regr.predict(x_test)
y_pred

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %% [markdown]
# # II Model_2 Sales with PC

# %% [markdown]
# we are building the model only on PC as per client requirment future 4Q sales predictions budget allocating 2020 june 17L 2020 sep 11L 2020 dec 9L 2021 march 16L

# %% [markdown]
# # 2.1 Model_2(direct)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
model=ols('Sales~PC',data=sales).fit()
model2=sm.stats.anova_lm(model)
model2
print(model.summary())

# %%
pre2=model.predict()
pre2

# %%
pre_2=pd.DataFrame(pre2,columns=['pre2'])
pre_2

# %%
res2=sales['Sales'].values-pre2
res2

# %%
res_2=pd.DataFrame(res2,columns=['res2'])
res_2

# %%
zscore2=pd.DataFrame(zscore(res2),columns=['zscore2'])
zscore2

# %%
sales2=pd.concat([sales,pre_2,res_2,zscore2],axis=1)
sales2
sales_2=pd.DataFrame(sales2)
sales_2

# %%
zscore2[zscore2['zscore2']>1.96]

# %%
zscore2[zscore2['zscore2']<-1.96]

# %%
b=sales_2.copy()
for i in range(0,len(b)):
    if(np.any(b['zscore2'].values[i]>1.96)):
        b['zscore2'].values[i]=0
    else:
        b['zscore2'].values[i]=1         
        test=b['zscore2']
        test
sales_2['dummy']=test
sales_2

# %% [markdown]
# # 2.2 Model_2 Applying(Square)

# %%
sales_2["sqr_PC"]=sales_2["PC"]**2
sales_2

# %%
x_PC=sales_2[["PC","sqr_PC"]]
y_PC=sales_2["Sales"]
x_PC

# %%
plt.scatter(y_PC,res2)
plt.xlabel("res_pc")
plt.ylabel("Sales")

# %%
x_train, x_test, y_train, y_test = train_test_split(x_PC, y_PC, test_size=0.20,random_state=0)

# %%
x_train

# %%
y_train

# %%
x_test

# %%
y_test

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
x_train1=sm.add_constant(x_train)
model=sm.OLS( y_train,x_train1).fit()
print(model.summary())
ols = linear_model.LinearRegression()

# %%
regr = linear_model.LinearRegression()
regr.fit(x_train,y_train)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# %%
y_pred = regr.predict(x_test)
y_pred

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %% [markdown]
# # 2.4 Model_2 Applying(SquareRoot)

# %%
sales_2["squareRoot_PC"]=sales_2["PC"]**(1/2)
sales_2

# %%
x_PC=sales_2[["PC","squareRoot_PC"]]
y_PC=sales_2["Sales"]
y_PC

# %%
x_train, x_test, y_train, y_test = train_test_split(x_PC, y_PC, test_size=0.20,random_state=0)

# %%
x_train

# %%
y_train

# %%
x_test

# %%
y_test

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
x_train1=sm.add_constant(x_train)
model=sm.OLS( y_train,x_train1).fit()
print(model.summary())
ols = linear_model.LinearRegression()

# %%
regr = linear_model.LinearRegression()
regr.fit(x_train,y_train)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# %%
y_pred = regr.predict(x_test)
y_pred

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %% [markdown]
# # 2.5 Model_2 Applying(Log10)

# %%
sales_2['log_PC'] = np.log10(sales_2['PC'])
(sales_2)

# %%
x_pc=sales_2[["PC","log_PC"]]
y_pc=sales_2["Sales"]
y_pc

# %%
x_train, x_test, y_train, y_test = train_test_split(x_pc, y_pc, test_size=0.20,random_state=0)

# %%
x_train

# %%
y_train

# %%
x_test

# %%
y_test

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
x_train1=sm.add_constant(x_train)
model=sm.OLS( y_train,x_train1).fit()
print(model.summary())
ols = linear_model.LinearRegression()

# %%
regr = linear_model.LinearRegression()
regr.fit(x_train,y_train)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# %% [markdown]
# y_pred = regr.predict(x_test)
# y_pred

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %% [markdown]
# # III Model_3 Sales with Advt and PC

# %% [markdown]
# we are building the model only on Advt and PC as per client requirment future 4Q sales predictions budget allocating 2020 june 17L 2020 sep 11L 2020 dec 9L 2021 march 16L

# %% [markdown]
# # 3.1 Model_3(direct)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
model=ols('Sales~Advt+PC',data=sales).fit()
model3=sm.stats.anova_lm(model)
model3
print(model.summary())

# %%
pre3=model.predict()
pre3

# %%
pre_3=pd.DataFrame(pre3,columns=['pre3'])
pre_3

# %%
res3=sales['Sales'].values-pre3
res3

# %%
res_3=pd.DataFrame(res3,columns=['res3'])
res_3

# %%
zscore3=pd.DataFrame(zscore(res3),columns=['zscore3'])
zscore3

# %%
zscore3[zscore3['zscore3']>1.96]

# %%
zscore3[zscore3['zscore3']<-1.96]

# %%
sales3=pd.concat([sales,pre_3,res_3,zscore3],axis=1)
sales3
sales_3=pd.DataFrame(sales3)
sales_3

# %% [markdown]
# # 3.2 Model_3 Applying(Dummy)

# %%
c=sales_3.copy()
for i in range(0,len(c)):
    if(np.any(c['zscore3'].values[i]<-1.96)):
        c['zscore3'].values[i]=0
    else:
        c['zscore3'].values[i]=1         
        test=c['zscore3']
        test
sales_3['dummy']=test
sales_3

# %% [markdown]
# # 3.3 Model_3 Applying(Square)

# %%
sales_3["sqr_pc"]=sales_3["PC"]**2
sales_3

# %%
x_adpc =sales_3[["Advt","PC","sqr_pc"]]
y_adpc = sales_3['Sales']
y_adpc

# %%
plt.scatter(y_adpc,res3)
plt.xlabel("res_adpc")
plt.ylabel("Sales")

# %%
x_train, x_test, y_train, y_test = train_test_split(x_adpc,y_adpc,test_size=0.20,random_state=0)

# %%
x_train

# %%
y_train

# %%
x_test

# %%
y_test

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
x_train1=sm.add_constant(x_train)
model=sm.OLS( y_train,x_train1).fit()
print(model.summary())
ols = linear_model.LinearRegression()

# %%
regr = linear_model.LinearRegression()
regr.fit(x_train,y_train)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# %%
y_pred = regr.predict(x_test)
y_pred

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %% [markdown]
# # 3.4 Model_3 Applying(Square Root)

# %%
sales_3["squareRoot_pc"]=sales_3["PC"]**(1/2)
sales_3

# %%
x_adpc=sales_3[["Advt","PC","squareRoot_pc"]]
y_adpc=sales_3["Sales"]
y_adpc

# %%
x_train, x_test, y_train, y_test = train_test_split(x_adpc,y_adpc,test_size=0.20,random_state=0)

# %%
x_train

# %%
y_train

# %%
x_test

# %%
y_test

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
x_train1=sm.add_constant(x_train)
model=sm.OLS( y_train,x_train1).fit()
print(model.summary())
ols = linear_model.LinearRegression()

# %%
regr = linear_model.LinearRegression()
regr.fit(x_train,y_train)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# %%
y_pred = regr.predict(x_test)
y_pred

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %% [markdown]
# # 3.5 Model_3 Applying(Log10)

# %%
sales_3['log_PC'] = np.log(sales_3['PC'])
(sales_3)

# %%
x_ADPC =sales_3[["Advt","PC","log_PC"]]
y_ADPC = sales_3['Sales']
x_ADPC

# %%
x_train, x_test, y_train, y_test = train_test_split(x_ADPC,y_ADPC,test_size=0.20,random_state=0)

# %%
x_train

# %%
y_train

# %%
x_test

# %%
y_test

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
x_train1=sm.add_constant(x_train)
model=sm.OLS( y_train,x_train1).fit()
print(model.summary())
ols = linear_model.LinearRegression()

# %%
regr = linear_model.LinearRegression()
regr.fit(x_train,y_train)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# %%
y_pred = regr.predict(x_test)
y_pred

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %%
x_test
y_test
